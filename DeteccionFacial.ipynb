# %% [markdown]
# # Practica de Detección de rosotros con OpenCV

# %% [markdown]
# ## Alumno: Carlos Antonio Rascon Carlos  16111750

# %%
#Importando librerias para mostrar imagenes de explicacion
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %% [markdown]
# La deteccion de rostros es una tecnica que identifica o localiza rosotrs humanos en imagenes digitales. Un ejemplo tipico de deteccion de rosotros ocurre cuando tomamos fotografias a traves de nuestros telefonos inteligentes y detecta instantaneamente rosotrs en la imagen. La deteccion de rosotros es diferente del reconocimiento de rostros. La deteccion de rotros detecta simplemente la presencia de rosotros en una imagen, mientras que el reconocimiento facial implica identificar de quien es el rostro. En esta practica, solo trataremos con el primero.

# %% [markdown]
# La deteccion de rostros se realiza mediante el uso de clasificadores. Un clasificador es esencialmente un algoritmo que decide si una imagen dada es positiva (cara) o negativa (no una cara). un lcasficador necesita ser entrenado en miles de imagenes con y sin caras. Afortunadamente, OpenCV ya tiene dos clasificadores de deteccion de rosotros previamente entrenados, que permiten usarse facilmente en un programa. Los dos clasificadores son:

# %% [markdown]
# Haar Classifier.

# %% [markdown]
# Local Binary Pattern(LBP) classifier.

# %% [markdown]
# En esta practica, solo discutiremos el clasificador Haar.

# %% [markdown]
# ### Haar feature-based cascade classifiers

# %% [markdown]
# Las caracteristicas tipo Haar son caracteristicas digitales utilizadas en el reconocimiento de objetos. Deben su nombre a su similitud intuitiva con las wavelets de Haar y se usaron en el primer detector facial en tiempo real. Paul viola y Michael Jones en su articulo titulado "Deteccion rapida de objetos usando una cascada mejorada de caracteristicas simples" utilizaron la idea del clasificador de Haar en las wavelets de Haar. Este clasificador es ampliamente utilizado para tareas como la deteccion de rostros en la industria de la vision por computadora.

# %% [markdown]
# El clasificador en cascada Haar emplea un enfoque de aprendizaje automatico para la deteccion de objetos visuales que es capaz de procesar imagenes extremadamente rapido y lograr altas tasas de deteccion. Esto puede atriburise a tres razones principales.

# %% [markdown]
# 1.El clasificador de Haar emplea el concepto 'imagen integral' que permite que las carateristicas utilizadas por el detector se calculen muy rapidamente.

# %% [markdown]
# 2.El algoritmo de aprendizaje se basa en el AdaBoost. Selecciona una pequeña cantidad de caracteristicas importantes de un conjunto grande y ofrece clasificadores altamente eficientes.

# %% [markdown]
# 3.Los clasificadores mas complejos se comnbinan para formar una 'cascada' que descarta las reginoes no faciales en una imagen, gastando asi mas computo en regiones prometedoras similares a objetos.

# %% [markdown]
# ### Como funciona el algoritmo en las imagenes en pasos:

# %% [markdown]
# ### 1. Extraccion de 'Caracteristicas de Haar'

# %% [markdown]
# Despues de que la enorme cantidad de datos de entrenamiento (en forma de imagenes) se introduce en el sistema, el clasifciador comienza extrayendo las caracteristicas de Haar de cada imagen. Las caracteristicas de Haar son unna especie de nucleos de convolucion que detectan principalmente si una caractersitica adecuada esta presente en una imagen o no. Algunos ejmplos de caracteristicas de Haar se mencionan a continuacion:

# %%
imagen1=mpimg.imread('imagen1.png')
imgplot = plt.imshow(imagen1)
plt.show()

# %% [markdown]
# Estas caracteristicas de Haar son como ventanas y se colocan sobre imagenes para calcular una sola caracteristica. La caracteristica es esencialmente un valor unico obtenido restando la suma de los pixeles debajo de la region blanca y la debajo del negro. El proceso se puede visualizar facilmente en el siguiente ejemplo.

# %%
imagen2=mpimg.imread('imagen2.png')
implot = plt.imshow(imagen2)
plt.show()
